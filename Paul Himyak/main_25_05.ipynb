# %% [markdown]
# <a href="https://colab.research.google.com/github/Untick/InspectrumClinic_RecSys/blob/Paul-Himyak-folder/Paul%20Himyak/main_25_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import uuid
import re
import numpy as np
import seaborn as sns
from datetime import datetime

from sklearn.model_selection import train_test_split 
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.utils import resample

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

from tensorflow.keras.layers import concatenate, Embedding, Conv1D, Input, Dense, Dropout, BatchNormalization, Flatten , SpatialDropout1D, Reshape, RepeatVector, GlobalMaxPooling1D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
import tensorflow.keras.losses as keras_losses
import tensorflow.keras.metrics as keras_metrics
from tensorflow.keras import utils



import gdown

# %%
dataset_url = "https://drive.google.com/uc?export=download&id=1ErXvN290PPthLGsb0ALpa_0aUDnvC0jg"
#dataset_url = "https://docs.google.com/spreadsheets/d/1ErXvN290PPthLGsb0ALpa_0aUDnvC0jg/edit?usp=share_link&ouid=113369956649761615778&rtpof=true&sd=true"
dataset_filename = "profpatolog_modified.xlsx"
#!wget -qc dataset_url -O dataset_filename
gdown.download(dataset_url, output=dataset_filename, quiet=True )
# Out:
# 'profpatolog_modified.xlsx'

# %%
df = pd.read_excel("profpatolog_modified.xlsx")

# %%
#Удаляем случайные вбросы
df.drop([843, 851, 1022, 1024], inplace = True)

#Убираем пустые колонки
empty_columns = df.columns[df.isna().all()]
df.drop(empty_columns, inplace = True, axis = 1)

# %%
del df['Unnamed: 0']

# %%
FIELD_CLIENT_AGE = "КлиентВозраст"
FIELD_CLIENT_BIRTH_DAY = "КлиентДатаРождения"
FIELD_CLIENT_GENDER = "КлиентПол"
FIELD_CLIENT_GENDER_M = 0
FIELD_CLIENT_GENDER_F = 1
FIELD_CONCLUSION = "ЗаключениеМК"
FIELD_CONCLUSION_FIT = 1
FIELD_CONCLUSION_PART_FIT = 2
FIELD_CONCLUSION_NOT_FIT = 0

FIELD_DISPANSARY_GROUP = "ДиспансернаяГруппа"
FIELD_DISPANSARY_GROUP_I = 0
FIELD_DISPANSARY_GROUP_II = 1
FIELD_DISPANSARY_GROUP_III = 2
FIELD_DISPANSARY_GROUP_OTHER = 3

FIELD_HARMFUL_FACTORS = "ВредныеФакторы"


FIELD_NEW_AGE_CATEGORY = "ВозрастКатегория"
FIELD_NEW_MKBS = "mkbs"

FIELD_CLIENT_PROFESSION = "Профессия"
FIELD_NEW_CLIENT_PROFESSION = "Profession"
FIELD_NEW_CLIENT_ADDITIONS = "Дополнения сводные"

# %%
additions_df = df.filter(regex="(?i)Дополнение_Значение$")

# %%
df[FIELD_NEW_CLIENT_ADDITIONS] = additions_df.apply(lambda row: row.tolist(), axis=1)

# %%
df = df.loc[:, ~df.columns.str.contains('Дополнение_Значение', case=False)]

# %%
df[FIELD_CONCLUSION].value_counts().plot(kind='bar')

# Настраиваем параметры графика
plt.title('Распределение значений FIELD_DISPANSARY_GROUP')
plt.xlabel('Значение')
plt.ylabel('Количество')
plt.show()

# %%
from datetime import datetime
class MyUtils:
  conclusion_map = {FIELD_CONCLUSION_FIT:'Годен', FIELD_CONCLUSION_PART_FIT:"Частично годен", FIELD_CONCLUSION_NOT_FIT: 'Негоден'}
  @classmethod
  def conclusion_labels(cls):
    return  [cls.conclusion_map[k] for k in sorted(cls.conclusion_map)]

  @classmethod
  def resolve_conclusion_map(cls,x):
    return cls.conclusion_map[x]
  @staticmethod  
  # Определяем функцию для расчета возраста на основе даты
  def resolve_birthdate_to_age(date):
    current_year = pd.Timestamp.now().year
    age = current_year - date.year
    return age
  def resolve_genger(x):
    if x == 'Мужской':
        return FIELD_CLIENT_GENDER_M
    elif x == 'Женский':
        return FIELD_CLIENT_GENDER_F
    else:
        return None

  def resolve_conclusion_binary(arg):
    try:
      if "Годен" == arg:
        return FIELD_CONCLUSION_FIT
      else:
        return FIELD_CONCLUSION_NOT_FIT
    except (TypeError):
        return None
  def resolve_conclusion(arg):
    try:
      if "Годен" == arg:
        return FIELD_CONCLUSION_FIT
      elif "Негоден" in arg:
        return FIELD_CONCLUSION_NOT_FIT
      elif "Годен" in arg:
        return FIELD_CONCLUSION_PART_FIT
      else:
        return FIELD_CONCLUSION_NOT_FIT
    except (TypeError):
        return None
  def resolve_dispansary_group(arg):
    try:
      if arg == "I":
        return FIELD_DISPANSARY_GROUP_I
      elif arg == "II":
        return FIELD_DISPANSARY_GROUP_II
      elif "III" in arg :
        return FIELD_DISPANSARY_GROUP_III
      else:
        return FIELD_DISPANSARY_GROUP_OTHER
    except (TypeError):
        return None
  def resolve_age_to_category(arg):
    outClass =int((arg-13)/5)
    outClass = max(0, min(10,outClass))
    return outClass

# %%
# Преобразование заключения в цифру
df[FIELD_CONCLUSION] = df[FIELD_CONCLUSION].apply(lambda x: MyUtils.resolve_conclusion(x))

# %%
# Разделим данные по значениям поля FIELD_CONCLUSION
fit = df[df[FIELD_CONCLUSION] == FIELD_CONCLUSION_FIT]
not_fit = df[df[FIELD_CONCLUSION] == FIELD_CONCLUSION_NOT_FIT]
part_fit = df[df[FIELD_CONCLUSION] == FIELD_CONCLUSION_PART_FIT]

# Увеличим меньшие классы до размера большего класса
n_samples = len(fit)
not_fit_upsampled = resample(not_fit, replace=True, n_samples=n_samples, random_state=42)
part_fit_upsampled = resample(part_fit, replace=True, n_samples=n_samples, random_state=42)

# Объединим данные и перемешаем их
df_balanced = pd.concat([fit, not_fit_upsampled, part_fit_upsampled])
df_balanced = df_balanced.sample(frac=1, random_state=42)

# %%
# Преобразование колонки возраста в цифровой вид
df[FIELD_CLIENT_AGE] = df[FIELD_CLIENT_BIRTH_DAY].apply(MyUtils.resolve_birthdate_to_age)

# разделение возраста на категории
df[FIELD_NEW_AGE_CATEGORY] = df[FIELD_CLIENT_AGE].apply(MyUtils.resolve_age_to_category)

# Пол в цифру
df[FIELD_CLIENT_GENDER] = df[FIELD_CLIENT_GENDER].apply(lambda x: MyUtils.resolve_genger(x) if pd.notnull(x) else x)

# Удалим неиспользованные колонки
del df[FIELD_CLIENT_BIRTH_DAY]
del  df[FIELD_CLIENT_AGE]

# %%
#Преобразование диспансерных групп в цифру
df[FIELD_DISPANSARY_GROUP] = df[FIELD_DISPANSARY_GROUP].apply(MyUtils.resolve_dispansary_group)

# %%
# Все колонки МКБ10
mkb_columns = df.filter(regex="(?i)МКБ10").columns

#Решил заменить пустые колонки на Z00.0
df[mkb_columns] = df[mkb_columns].fillna(value='Z00.0')

# объединяем значения из нескольких столбцов в одну колонку, удаляем дубликаты, чтоб уменьшить разреженность 
#df['mkb'] = df.apply(lambda row: list(set([row[mkb_col_name] for mkb_col_name in mkb_columns if not pd.isna(row[mkb_col_name]) ])), axis=1)
df[FIELD_NEW_MKBS] = df.apply(lambda row: list(set([row[mkb_col_name] for mkb_col_name in mkb_columns])), axis=1)

# исключаем из фрейма все МКБ поскольку теперь у нас есть одна общая mkbs
df = df.loc[:, ~df.columns.str.contains('мкб10', case=False)]

# %%
# разделяем факторы по одному значению
df[FIELD_HARMFUL_FACTORS] = df[FIELD_HARMFUL_FACTORS].str.split(",")
# Out:
# <ipython-input-58-593652ce6884>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[FIELD_HARMFUL_FACTORS] = df[FIELD_HARMFUL_FACTORS].str.split(",")

# %%
df.dropna(inplace = True)
# Out:
# <ipython-input-59-d1ada024d2eb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace = True)

# %%
df[FIELD_HARMFUL_FACTORS]
# Out:
# 0                [11.4]
# 1               [4.2.5]
# 2               [4.2.5]
# 3                [11.1]
# 4                [11.1]
#              ...
# 1960    [4.4, 4.5, 6.1]
# 1961    [4.4, 4.5, 6.1]
# 1962              [4.4]
# 1972          [3.1.8.2]
# 1973       [4.2.5, 6.1]
# Name: ВредныеФакторы, Length: 1562, dtype: object

# %% [markdown]
# Подготавливаю все однозначные цифровые данные в OHE

# %%
# Объединяю категориальные значения в OHE
df_ohe  = pd.get_dummies(df[[FIELD_CLIENT_GENDER, FIELD_DISPANSARY_GROUP, FIELD_NEW_AGE_CATEGORY]],  columns = [FIELD_CLIENT_GENDER, FIELD_DISPANSARY_GROUP, FIELD_NEW_AGE_CATEGORY] )
xTrain0 = df_ohe.values
xTrain0.shape
# Out:
# (1562, 16)

# %%
df[FIELD_CONCLUSION].value_counts()
# Out:
# 1.0    1428
# 2.0     126
# 0.0       8
# Name: ЗаключениеМК, dtype: int64

# %%
yTrain =  pd.get_dummies(df[FIELD_CONCLUSION]).values

# %%
FIELD_CONCLUSION_PART_FIT
# Out:
# 2

# %%
Y_CLASSES = yTrain.shape[1]
Y_CLASSES
# Out:
# 3

# %%
yTrain.shape
# Out:
# (1562, 3)

# %% [markdown]
# Поскольку теперь mkb колонка одна, то пришла мысль поработать с ней как эмбедингом

# %%
df[FIELD_NEW_MKBS].explode().unique()
# Out:
# array(['Z00.0', 'I11.9', 'H52.1', 'H52.2', 'H53.0', 'K29.3', 'I70',
#        'H90.5', 'G90.9', 'H52.0', 'S68.2', 'N60.2', 'E11.9', 'K29.6',
#        'M42.1', 'D25', 'I69.4', 'N83.2', 'H90.3', 'K44.9', 'N80.0',
#        'G99.0', 'G12.1', 'K81.9', 'H11.0', 'G25.0', 'K26.9', 'K86.1',
#        'H91.1', 'H74.1', 'I67.2', 'N28.1', 'L40.0', 'I83.9', 'H93.0',
#        'D25.9', 'I25.8', 'K80.5', 'F06.6', 'K40.9', 'E11.8', 'E10.9',
#        'T94.0', 'F10.7', 'D35.2', 'L20.8', 'K29.5', 'H50.9', 'K80.2',
#        'I25.2', 'Q12.0', 'S51.9', 'F06.7', 'H25.0', 'I66.9', 'I67.9',
#        'K29.8', 'T90.4', 'H40.1', 'H90.4', 'F41.0', 'R25.1', 'K29.7',
#        'H47.2', 'J33.0', 'H66.1', 'K26.7', 'H02.4', 'I49.9', 'H01.0',
#        'F98.5', 'I49.8', 'J45.8', 'H35.0', 'H17.1', 'J30.1', 'F07.0',
#        'G58.9', 'J37.0', 'H25.1', 'I25.9', 'K82.9', 'J45.9', 'G90.8',
#        'K29.4'], dtype=object)

# %%
tokenizer_mkb = Tokenizer()
tokenizer_mkb.fit_on_texts(np.array(df[FIELD_NEW_MKBS]))
mkb_vocab_size = len(tokenizer_mkb.word_index) + 1
mkb_vocab_size
# Out:
# 86

# %%
xMkbIndexed = tokenizer_mkb.texts_to_sequences(df[FIELD_NEW_MKBS])

# %%
np_len = np.vectorize(len)
mkb_max_len = np_len(xMkbIndexed).max()
mkb_max_len
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2336: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   args = [asarray(arg) for arg in args]
# 5

# %%
xMkbIndexedPadded = pad_sequences(xMkbIndexed, maxlen=mkb_max_len, padding='post')
xTrainMkb = xMkbIndexedPadded

# %%
xMkbIndexedPadded.shape
# Out:
# (1562, 5)

# %% [markdown]
# вредные факторы тоже токенизировал для дальнейшего использования его в эмбединге

# %%
#tokenizing harm codes
tokenizer_harmfull = Tokenizer()
tokenizer_harmfull.fit_on_texts(df[FIELD_HARMFUL_FACTORS])
harmfull_vocab_size = len(tokenizer_harmfull.word_index) + 1
xTrainHarmfulIndexes = tokenizer_harmfull.texts_to_sequences(df[FIELD_HARMFUL_FACTORS])
harm_max_len = np_len(xTrainHarmfulIndexes).max()
harm_max_len
# Out:
# 13

# %%
xTrainHarmfulIndexesPadded = pad_sequences(xTrainHarmfulIndexes, maxlen=harm_max_len, padding='post')
xTrainHarmFull = xTrainHarmfulIndexesPadded
xTrainHarmFull.shape
# Out:
# (1562, 13)

# %% [markdown]
# Профессии токенизировал тоже будут эмбеддингами

# %%
maxWordsCount = 1000 
tokenizer_prof = Tokenizer(num_words=maxWordsCount, filters='!"#$%&()*+,-–—./:;<=>?@[\]^_`{|}~\t\n\xa0', lower=True, split=' ', oov_token='unknown', char_level=False)
tokenizer_prof.fit_on_texts(df[FIELD_CLIENT_PROFESSION])

# %%
prof_vocab_size = len(tokenizer_prof.word_index) + 1
prof_vocab_size
# Out:
# 514

# %%
xTrainProfIndexed = tokenizer_prof.texts_to_sequences(df[FIELD_CLIENT_PROFESSION])
prof_max_len = np_len(xTrainProfIndexed).max()
prof_max_len
xTrainProfIndexedPadded = pad_sequences(xTrainProfIndexed, maxlen=prof_max_len, padding='post')
xTrainProf = xTrainProfIndexedPadded
xTrainProf.shape
# Out:
# (1562, 12)

# %% [markdown]
# Дополнительные комментарии специалистов

# %%
tokenizer_additions = Tokenizer(num_words=1000, filters='!"#$%&()*+,-–—./:;<=>?@[\]^_`{|}~\t\n\xa0', lower=True, split=' ', oov_token='unknown', char_level=False)
tokenizer_additions.fit_on_texts(df[FIELD_NEW_CLIENT_ADDITIONS])

# %%
xTrainAdditionsIndexed = tokenizer_additions.texts_to_sequences(df[FIELD_NEW_CLIENT_ADDITIONS])
additions_max_len = np_len(xTrainAdditionsIndexed).max()
additions_max_len
xTrainAdditionsIndexedPadded = pad_sequences(xTrainProfIndexed, maxlen=additions_max_len, padding='post')
xTrainAdditions = xTrainAdditionsIndexedPadded
xTrainAdditions.shape

# %%
x_train, x_test, x_train_mkb, x_test_mkb, x_train_harmfull, x_test_harmfull, x_train_prof, x_test_prof, x_train_additions, x_test_additions,  y_train, y_test = train_test_split(xTrain0,
                                                                                                              xTrainMkb,
                                                                                                              xTrainHarmFull,
                                                                                                              xTrainProf,
                                                                                                              xTrainAdditions,                                                                                                              
                                                                                                              yTrain, 
                                                                                                              test_size=0.2,
                                                                                                              shuffle = False)

# %%
# На этот вход подаются все OHE
input0 = Input((x_train.shape[1],))
# Сюда подаются mkb в виде последовательности токенов , поскольку они уже объединины в одой колонке
input_mkb = Input((x_train_mkb.shape[1],))
# Сюда подаются вредные факторы тоже аналогично мкб , как будто это предложение из токенов 
input_harmfull = Input((x_train_harmfull.shape[1],))
# Сюда подаются профессии , тоже как предложение токенов
input_prof = Input((x_train_prof.shape[1],))

# %%
input_harmfull.shape
# Out:
# TensorShape([None, 13])

# %%
input_prof.shape
# Out:
# TensorShape([None, 12])

# %%
x_train_mkb[:3,:]
# Out:
# array([[1, 0, 0, 0, 0],
#        [1, 2, 0, 0, 0],
#        [1, 3, 0, 0, 0]], dtype=int32)

# %%
def create_model1(input0, input_mkb, input_harmfull, input_prof):
  x0 = BatchNormalization()(input0)
  x0 = Dense(1024, activation='relu') (x0)
  x0 = BatchNormalization()(x0)
  x0 = Dropout(0.3)(x0)
  x0 = Dense(768, activation='sigmoid')(x0)
  x0 = BatchNormalization()(x0)
  x0 = Dropout(0.3)(x0)
  x0 = Dense(512, activation='sigmoid')(x0)

  x1 = Embedding(mkb_vocab_size, 128,  input_length = mkb_max_len)(input_mkb)
  x1 = SpatialDropout1D(0.2)(x1)
  x1 = Dense(100, activation = 'sigmoid')(x1)
  #x1 = Flatten()(x1)

  x2 = Embedding(harmfull_vocab_size, 128, input_length = harm_max_len)(input_harmfull)
  x2 = SpatialDropout1D(0.2)(x2)
  x2 = Dense(100, activation = 'sigmoid')(x2)
  #x2 = Flatten()(x2)

 # x3 = Embedding(prof_vocab_size, 256, input_length = prof_max_len)(input_prof)
 # x3 = SpatialDropout1D(0.2)(x3)
  x3 = Dense(100, activation = 'sigmoid')(input_prof)
  x3 = Reshape((1, 100))(x3)

  #x3 = Flatten()(x3)

  x_ = concatenate([x1, x2, x3], axis = -2)
  x_ = Flatten()(x_)
  x = concatenate([x0, x_])


  x = Dense(800, activation = 'relu')(x)
  x = BatchNormalization()(x)
  x = Dropout(0.3)(x)
  x = Dense(Y_CLASSES, activation='softmax')(x)

  return Model((input0, input_mkb, input_harmfull, input_prof), x )

# %% [markdown]
# Модель 1

# %%
model1 = create_model1(input0, input_mkb, input_harmfull, input_prof)
utils.plot_model(model1, dpi=60, show_shapes = True)

# %%
model1.compile(optimizer = Adam(learning_rate = 1e-5), loss = keras_losses.categorical_crossentropy, metrics=['mae', 'accuracy'])

# %%
# Визуальная оценка ошибки на обучающей и проверочной выборках

def compare_sharp_loss (history, x_size, y_size):
  
  plt.figure(figsize=(x_size,y_size))
  plt.plot(history.history['loss'], 
         label='Ошибка на обучающей выборке')
  
  plt.plot(history.history['val_loss'], 
         label='Ошибка проверочном наборе')
  plt.xlabel('Эпоха обучения')
  plt.ylabel('Средняя ошибка')
  plt.legend()
  plt.show()

# %%
history = model1.fit([x_train, x_train_mkb, x_train_harmfull, x_train_prof],
                    y_train,
                    batch_size=32,
                    epochs = 100,
                    validation_split = 0.2,
                    verbose = 1)
# Out:
# Epoch 1/100
# 32/32 [==============================] - 6s 77ms/step - loss: 1.3967 - mae: 0.4321 - accuracy: 0.3644 - val_loss: 0.8588 - val_mae: 0.3838 - val_accuracy: 0.9000
# Epoch 2/100
# 32/32 [==============================] - 3s 97ms/step - loss: 1.3591 - mae: 0.4258 - accuracy: 0.3954 - val_loss: 0.9259 - val_mae: 0.4023 - val_accuracy: 0.1000
# Epoch 3/100
# 32/32 [==============================] - 3s 102ms/step - loss: 1.3192 - mae: 0.4164 - accuracy: 0.4044 - val_loss: 0.9137 - val_mae: 0.3991 - val_accuracy: 0.9000
# Epoch 4/100
# 32/32 [==============================] - 3s 82ms/step - loss: 1.3250 - mae: 0.4252 - accuracy: 0.3874 - val_loss: 0.9240 - val_mae: 0.4017 - val_accuracy: 0.9000
# Epoch 5/100
# 32/32 [==============================] - 2s 53ms/step - loss: 1.2769 - mae: 0.4198 - accuracy: 0.4064 - val_loss: 0.8691 - val_mae: 0.3855 - val_accuracy: 0.9000
# Epoch 6/100
# 32/32 [==============================] - 2s 56ms/step - loss: 1.2492 - mae: 0.4127 - accuracy: 0.4114 - val_loss: 0.8708 - val_mae: 0.3858 - val_accuracy: 0.9000
# Epoch 7/100
# 32/32 [==============================] - 2s 55ms/step - loss: 1.2515 - mae: 0.4111 - accuracy: 0.4284 - val_loss: 0.9081 - val_mae: 0.3960 - val_accuracy: 0.9000
# Epoch 8/100
# 32/32 [==============================] - 2s 57ms/step - loss: 1.2573 - mae: 0.4114 - accuracy: 0.4364 - val_loss: 0.9704 - val_mae: 0.4133 - val_accuracy: 0.8640
# Epoch 9/100
# 32/32 [==============================] - 2s 57ms/step - loss: 1.2279 - mae: 0.4132 - accuracy: 0.4094 - val_loss: 0.9659 - val_mae: 0.4116 - val_accuracy: 0.8320
# Epoch 10/100
# 32/32 [==============================] - 3s 80ms/step - loss: 1.2503 - mae: 0.4163 - accuracy: 0.4174 - val_loss: 0.8163 - val_mae: 0.3679 - val_accuracy: 0.9000
100
# 32/32 [==============================] - 2s 58ms/step - loss: 0.4652 - mae: 0.2171 - accuracy: 0.8488 - val_loss: 0.3849 - val_mae: 0.1903 - val_accuracy: 0.8840
# Epoch 100/100
# 32/32 [==============================] - 2s 58ms/step - loss: 0.4769 - mae: 0.2193 - accuracy: 0.8418 - val_loss: 0.3650 - val_mae: 0.1804 - val_accuracy: 0.8920

# %%
model1.save("drive/MyDrive/prof_patolog/model1.h5")

# %%
# Out:
# 0

# %%
#дообучение
model1.compile(optimizer = Adam(learning_rate = 5e-6), loss = keras_losses.categorical_crossentropy, metrics=['mae', 'accuracy'])
history = model1.fit([x_train, x_train_mkb, x_train_harmfull, x_train_prof], #model1.fit([x_train, x_train_mkb, x_train_harmfull, x_train_prof],
                    y_train,
                    batch_size=32,
                    epochs = 50,
                    validation_split = 0.2,
                    verbose = 1)
# Out:
# Epoch 1/50
# 32/32 [==============================] - 54s 68ms/step - loss: 0.4694 - mae: 0.2155 - accuracy: 0.8579 - val_loss: 0.3432 - val_mae: 0.1708 - val_accuracy: 0.9000
# Epoch 2/50
# 32/32 [==============================] - 2s 55ms/step - loss: 0.4630 - mae: 0.2150 - accuracy: 0.8599 - val_loss: 0.3726 - val_mae: 0.1852 - val_accuracy: 0.8840
# Epoch 3/50
# 32/32 [==============================] - 2s 53ms/step - loss: 0.4443 - mae: 0.2090 - accuracy: 0.8699 - val_loss: 0.3602 - val_mae: 0.1797 - val_accuracy: 0.9000
# Epoch 4/50
# 32/32 [==============================] - 2s 52ms/step - loss: 0.4650 - mae: 0.2170 - accuracy: 0.8609 - val_loss: 0.3346 - val_mae: 0.1660 - val_accuracy: 0.9000
# Epoch 5/50
# 32/32 [==============================] - 2s 76ms/step - loss: 0.4445 - mae: 0.2082 - accuracy: 0.8749 - val_loss: 0.3306 - val_mae: 0.1636 - val_accuracy: 0.8960
# Epoch 6/50
# 32/32 [==============================] - 3s 87ms/step - loss: 0.4594 - mae: 0.2144 - accuracy: 0.8579 - val_loss: 0.3516 - val_mae: 0.1752 - val_accuracy: 0.9000
# Epoch 7/50
# 32/32 [==============================] - 2s 57ms/step - loss: 0.4535 - mae: 0.2108 - accuracy: 0.8559 - val_loss: 0.3762 - val_mae: 0.1874 - val_accuracy: 0.8880
# Epoch 8/50
# 32/32 [==============================] - 2s 55ms/step - loss: 0.4402 - mae: 0.2053 - accuracy: 0.8739 - val_loss: 0.3562 - val_mae: 0.1760 - val_accuracy: 0.8960
# Epoch 9/50
# 32/32 [==============================] - 2s 55ms/step - loss: 0.4356 - mae: 0.2044 - accuracy: 0.8739 - val_loss: 0.3566 - val_mae: 0.1770 - val_accuracy: 0.9040
# Epoch 10/50
# 32/32 [==============================] - 2s 55ms/step - loss: 0.4404 - mae: 0.2060 - accuracy: 0.8729 - val_loss: 0.3746 - val_mae: 0.1858 - val_accuracy: 0.8920
# Epoch 11/50
# 32/32 [==============================] - 2s 56ms/step - loss: 0.4400 - mae: 0.2043 - accuracy: 0.8709 - val_loss: 0.3796 - val_mae: 0.1888 - val_accuracy: 0.8920
# Epoch 12/50
# 32/32 [==============================] - 2s 67ms/step - loss: 0.4276 - mae: 0.1992 - accuracy: 0.8869 - val_loss: 0.4183 - val_mae: 0.2056 - val_accuracy: 0.8640
# Epoch 13/50
# 32/32 [==============================] - 3s 92ms/step - loss: 0.4206 - mae: 0.1977 - accuracy: 0.8839 - val_loss: 0.3984 - val_mae: 0.1969 - val_accuracy: 0.8720
# Epoch 14/50
# 32/32 [==============================] - 2s 55ms/step - loss: 0.
# Epoch 47/50
# 32/32 [==============================] - 2s 79ms/step - loss: 0.3395 - mae: 0.1624 - accuracy: 0.9049 - val_loss: 0.3178 - val_mae: 0.1560 - val_accuracy: 0.8840
# Epoch 48/50
# 32/32 [==============================] - 3s 92ms/step - loss: 0.3522 - mae: 0.1662 - accuracy: 0.8819 - val_loss: 0.3009 - val_mae: 0.1468 - val_accuracy: 0.9000
# Epoch 49/50
# 32/32 [==============================] - 2s 57ms/step - loss: 0.3591 - mae: 0.1669 - accuracy: 0.8979 - val_loss: 0.2793 - val_mae: 0.1336 - val_accuracy: 0.8920
# Epoch 50/50
# 32/32 [==============================] - 2s 56ms/step - loss: 0.3306 - mae: 0.1628 - accuracy: 0.9139 - val_loss: 0.2763 - val_mae: 0.1322 - val_accuracy: 0.9040

# %%
compare_sharp_loss(history, 10, 4)

# %% [markdown]
# Модель 2

# %%
x0 = BatchNormalization()(input0)
x0 = Dense(1024, activation='relu') (x0)
x0 = BatchNormalization()(x0)
x0 = Dropout(0.3)(x0)
x0 = Dense(768, activation='sigmoid')(x0)
x0 = BatchNormalization()(x0)
x0 = Dropout(0.3)(x0)
x0 = Dense(512, activation='sigmoid')(x0)

x1 = Embedding(mkb_vocab_size, 128, input_length = mkb_max_len)(input_mkb)
x1 = SpatialDropout1D(0.2)(x1)
x1 = Conv1D(128,3, activation = 'relu', padding='same')(x1)
x1 = GlobalMaxPooling1D()(x1)
x1 = Dense(256, activation = 'sigmoid')(x1)
#x1 = Flatten()(x1)

x2 = Embedding(harmfull_vocab_size, 128, input_length = harm_max_len)(input_harmfull)
x2 = SpatialDropout1D(0.2)(x2)
x2 = Conv1D(128,3, activation = 'relu', padding='same')(x2)
x2 = GlobalMaxPooling1D()(x2)
x2 = Dense(256, activation = 'relu')(x2)
#x2 = Flatten()(x2)

x3 = Embedding(prof_vocab_size, 256, input_length = prof_max_len)(input_prof)
x3 = SpatialDropout1D(0.2)(x3)
x3 = Conv1D(128,2, activation = 'relu', padding='same')(x3)
x3 = GlobalMaxPooling1D()(x3)
x3 = Dense(256, activation = 'relu')(x3)
#x3 = Flatten()(x3)

x = concatenate([x0,x1, x3, x3])
x = Dense(800, activation = 'relu')(x)
x = BatchNormalization()(x)
x = Dropout(0.3)(x)
x = Dense(Y_CLASSES, activation='softmax')(x)

model2 =  Model((input0, input_mkb, input_harmfull, input_prof), x )
model2.compile(optimizer = Adam(learning_rate = 1e-4), loss = keras_losses.mse, metrics=[keras_metrics.mae])

# %%
utils.plot_model(model2, dpi=60, show_shapes = True)

# %%
print(x_train.shape,x_train_mkb.shape, x_train_harmfull.shape, x_train_prof.shape)
# Out:
# (1249, 16) (1249, 5) (1249, 13) (1249, 12)

# %%
history = model2.fit([x_train, x_train_mkb, x_train_harmfull, x_train_prof],
                    y_train,
                    batch_size=32,
                    epochs = 70,
                    validation_split = 0.20,
                    verbose = 1)
# Out:
# Epoch 1/70
# 32/32 [==============================] - 4s 38ms/step - loss: 0.2482 - mean_absolute_error: 0.3721 - val_loss: 0.1808 - val_mean_absolute_error: 0.3990
# Epoch 2/70
# 32/32 [==============================] - 1s 47ms/step - loss: 0.1586 - mean_absolute_error: 0.2251 - val_loss: 0.1322 - val_mean_absolute_error: 0.3318
# Epoch 3/70
# 32/32 [==============================] - 1s 44ms/step - loss: 0.1434 - mean_absolute_error: 0.1916 - val_loss: 0.0979 - val_mean_absolute_error: 0.2785
# Epoch 4/70
# 32/32 [==============================] - 1s 30ms/step - loss: 0.1347 - mean_absolute_error: 0.1737 - val_loss: 0.1016 - val_mean_absolute_error: 0.2858
# Epoch 5/70
# 32/32 [==============================] - 1s 30ms/step - loss: 0.1383 - mean_absolute_error: 0.1812 - val_loss: 0.0991 - val_mean_absolute_error: 0.2750
# Epoch 6/70
# 32/32 [==============================] - 1s 29ms/step - loss: 0.1374 - mean_absolute_error: 0.1747 - val_loss: 0.0948 - val_mean_absolute_error: 0.2510
# Epoch 7/70
# 32/32 [==============================] - 1s 29ms/step - loss: 0.1348 - mean_absolute_error: 0.1729 - val_loss: 0.0894 - val_mean_absolute_error: 0.2101
# Epoch 8/70
# 32/32 [==============================] - 1s 30ms/step - loss: 0.1347 - mean_absolute_error: 0.1718 - val_loss: 0.0956 - val_mean_absolute_error: 0.1794
# Epoch 9/70
# 32/32 [==============================] - 1s 30ms/step - loss: 0.1387 - mean_absolute_error: 0.1742 - val_loss: 0.0977 - val_mean_absolute_error: 0.1563
# Epoch 10/70
# 32/32 [==============================] - 1s 30ms/step - loss: 0.1391 - mean_absolute_error: 0.1739 - val_loss: 0.0936 - val_mean_absolute_error: 0.1283
# Epoch 11/70
# 32/32 [==============================] - 1s 31ms/step - loss: 0.1345 - mean_absolute_error: 0.1691 - val_loss: 0.0955 - val_mean_absolute_error: 0.1251
# Epoch 12/70
# 32/32 [==============================] - 1s 32ms/step - loss: 0.1302 - mean_absolute_error: 0.1662 - val_loss: 0.0960 - val_mean_absolute_error: 0.1266
# Epoch 13/70
# 32/32 [==============================] - 1s 31ms/step - loss: 0.1300 - mean_absolute_error: 0.1662 - val_loss: 0.0953 - val_mean_absolute_error: 0.1226
# Epoch 14/70
# 32/32 [==============================] - 1s 45ms/step - loss: 0.1341 - mean_absolute_error: 0.1745 - val_loss: 0.0964 - val_mean_absolute_error: 0.1217
# Epoch 15/70
# 32/32 [==============================] - 2s 49ms/step - loss: 0.1310 - mean_absolute_error: 0.1649 - val_loss: 0.0965 - val_mean_absolute_error: 0.1212
# Epoch 16/70
# 32/32 [==============================] - 1s 34ms/step - loss: 0.1323 - mean_absolute_error: 0.1668 - val_loss: 0.0986 - val_mean_absolute_error: 0.1221
# Epoch 17/70
# 32/32 [==============================] - 1s 33ms/step - loss: 0.1273 - mean_absolute_error: 0.1604 - val_loss: 0.0962 - val_mean_absolute_error: 0.1238
# Epoch 18/70
# 32/32 [==============================] - 1s 32ms/step - loss: 0.1297 - mean_absolute_error: 0.1664 - val_loss: 0.0982 - val_mean_absolute_error: 0.1199
# Epoch 19/70
# 32/32 [==============================] - 1s 33ms/step - loss: 0.1296 - mean_absolute_error: 0.1625 - val_loss: 0.0996 - val_mean_absolute_error: 0.1171
# Epoch 20/70
# 32/32 [==============================] - 1s 32ms/step - loss: 0.1287 - mean_absolute_error: 0.1643 - val_loss: 0.0985 - val_mean_absolute_error: 0.1198
# Epoch 21/70
# 32/32 [==============================] - 1s 32ms/step - loss: 0.1296 - mean_absolute_error: 0.1649 - val_loss: 0.0995 - val_mean_absolute_error: 0.1262
# Epoch 22/70
# 32/32 [==============================] - 1s 33ms/step - loss: 0.1289 - mean_absolute_error: 0.1632 - val_loss: 0.0997 - val_mean_absolute_error: 0.1257
# Epoch 23/70
# 32/32 [==============================] - 1s 33ms/step - loss: 0.1291 - mean_absolute_error: 0.1636 - val_loss: 0.0994 - val_mean_absolute_error: 0.1229
# Epoch 24/70
# 32/32 [==============================] - 1s 32ms/step - loss: 0.1269 - mean_absolute_error: 0.1634 - val_loss: 0.0998 - val_mean_absolute_error: 0.1219
# Epoch 25/70
# 32/32 [==============================] - 1s 40ms/step - loss: 0.1269 - mean_absolute_error: 0.1637 - val_loss: 0.0999 - val_mean_absolute_error: 0.1247
# Epoch 26/70
# 32/32 [==============================] - 2s 53ms/step - loss: 0.1270 - mean_absolute_error: 0.1599 - val_loss: 0.1000 - val_mean_absolute_error: 0.1270
# Epoch 27/70
# 32/32 [==============================] - 1s 35ms/step - loss: 0.1310 - mean_absolute_error: 0.1661 - val_loss: 0.1025 - val_mean_absolute_error: 0.1301
# Epoch 28/70
# 32/32 [==============================] - 1s 30ms/step - loss: 0.1324 - mean_absolute_error: 0.1727 - val_loss: 0.1009 - val_mean_absolute_error: 0.1292
# Epoch 29/70
# 32/32 [==============================] - 1s 32ms/step - loss: 0.1273 - mean_absolute_error: 0.1646 - val_loss: 0.1043 - val_mean_absolute_error: 0.1333
# Epoch 30/70
# 32/32 [==============================] - 1s 32ms/step - loss: 0.1232 - mean_absolute_error: 0.1606 - val_loss: 0.1004 - val_mean_absolute_error: 0.1277
# Epoch 31/70
# 32/32 [==============================] - 1s 31ms/step - loss: 0.1278 - mean_absolute_error: 0.1632 - val_loss: 0.0991 - val_mean_absolute_error: 0.1267
# Epoch 32/70
# 32/32 [==============================] - 1s 30ms/step - loss: 0.1255 - mean_absolute_error: 0.1618 - val_loss: 0.1042 - val_mean_absolute_error: 0.1315
# Epoch 33/70
# 32/32 [==============================] - 1s 31ms/step - loss: 0.1260 - mean_absolute_error: 0.1624 - val_loss: 0.1053 - val_mean_absolute_error: 0.1360
# Epoch 34/70
# 32/32 [==============================] - 1s 31ms/step - loss: 0.1307 - mean_absolute_error: 0.1700 - val_loss: 0.0996 - val_mean_absolute_error: 0.1239
# Epoch 35/70
# 32/32 [==============================] - 1s 30ms/step - loss: 0.1257 - mean_absolute_error: 0.1653 - val_loss: 0.0950 - val_mean_absolute_error: 0.1193
# Epoch 36/70
# 32/32 [==============================] - 1s 29ms/step - loss: 0.1238 - mean_absolute_error: 0.1602 - val_loss: 0.0988 - val_mean_absolute_error: 0.1264
# Epoch 37/70
# 32/32 [==============================] - 1s 36ms/step - loss: 0.1224 - mean_absolute_error: 0.1569 - val_loss: 0.0982 - val_mean_absolute_error: 0.1186
# Epoch 38/70
# 32/32 [==============================] - 2s 47ms/step - loss: 0.1227 - mean_absolute_error: 0.1584 - val_loss: 0.0999 - val_mean_absolute_error: 0.1237
# Epoch 39/70
# 32/32 [==============================] - 1s 40ms/step - loss: 0.1185 - mean_absolute_error: 0.1558 - val_loss: 0.1012 - val_mean_absolute_error: 0.1292
# Epoch 40/70
# 32/32 [==============================] - 1s 31ms/step - loss: 0.1245 - mean_absolute_error: 0.1643 - val_loss: 0.1014 - val_mean_absolute_error: 0.1257
# Epoch 41/70
# 32/32 [==============================] - 1s 30ms/step - loss: 0.1248 - mean_absolute_error: 0.1635 - val_loss: 0.0973 - val_mean_absolute_error: 0.1224
# Epoch 42/70
# 32/32 [==============================] - 1s 30ms/step - loss: 0.1228 - mean_absolute_error: 0.1605 - val_loss: 0.1032 - val_mean_absolute_error: 0.1294
# Epoch 43/70
# 32/32 [==============================] - 1s 31ms/step - loss: 0.1178 - mean_absolute_error: 0.1583 - val_loss: 0.0982 - val_mean_absolute_error: 0.1272
# Epoch 44/70
# 32/32 [==============================] - 1s 31ms/step - loss: 0.1184 - mean_absolute_error: 0.1601 - val_loss: 0.0981 - val_mean_absolute_error: 0.1205
# Epoch 45/70
# 32/32 [==============================] - 1s 30ms/step - loss: 0.1224 - mean_absolute_error: 0.1627 - val_loss: 0.1029 - val_mean_absolute_error: 0.1255
# Epoch 46/70
# 32/32 [==============================] - 1s 30ms/step - loss: 0.1197 - mean_absolute_error: 0.1621 - val_loss: 0.1020 - val_mean_absolute_error: 0.1341
# Epoch 47/70
# 32/32 [==============================] - 1s 29ms/step - loss: 0.1153 - mean_absolute_error: 0.1543 - val_loss: 0.0988 - val_mean_absolute_error: 0.1303
# Epoch 48/70
# 32/32 [==============================] - 1s 30ms/step - loss: 0.1149 - mean_absolute_error: 0.1572 - val_loss: 0.0997 - val_mean_absolute_error: 0.1294
# Epoch 49/70
# 32/32 [==============================] - 1s 37ms/step - loss: 0.1145 - mean_absolute_error: 0.1574 - val_loss: 0.1013 - val_mean_absolute_error: 0.1347
# Epoch 50/70
# 32/32 [==============================] - 1s 44ms/step - loss: 0.1167 - mean_absolute_error: 0.1593 - val_loss: 0.1058 - val_mean_absolute_error: 0.1430
# Epoch 51/70
# 32/32 [==============================] - 1s 40ms/step - loss: 0.1101 - mean_absolute_error: 0.1579 - val_loss: 0.1005 - val_mean_absolute_error: 0.1445
# Epoch 52/70
# 32/32 [==============================] - 1s 30ms/step - loss: 0.1067 - mean_absolute_error: 0.1597 - val_loss: 0.1005 - val_mean_absolute_error: 0.1489
# Epoch 53/70
# 32/32 [==============================] - 1s 30ms/step - loss: 0.0956 - mean_absolute_error: 0.1600 - val_loss: 0.1128 - val_mean_absolute_error: 0.1902
# Epoch 54/70
# 32/32 [==============================] - 1s 30ms/step - loss: 0.0865 - mean_absolute_error: 0.1501 - val_loss: 0.0962 - val_mean_absolute_error: 0.1643
# Epoch 55/70
# 32/32 [==============================] - 1s 31ms/step - loss: 0.0801 - mean_absolute_error: 0.1348 - val_loss: 0.0999 - val_mean_absolute_error: 0.1788
# Epoch 56/70
# 32/32 [==============================] - 1s 30ms/step - loss: 0.0801 - mean_absolute_error: 0.1382 - val_loss: 0.1075 - val_mean_absolute_error: 0.1898
# Epoch 57/70
# 32/32 [==============================] - 1s 31ms/step - loss: 0.0732 - mean_absolute_error: 0.1349 - val_loss: 0.1154 - val_mean_absolute_error: 0.2091
# Epoch 58/70
# 32/32 [==============================] - 1s 29ms/step - loss: 0.0576 - mean_absolute_error: 0.1288 - val_loss: 0.0846 - val_mean_absolute_error: 0.1702
# Epoch 59/70
# 32/32 [==============================] - 1s 31ms/step - loss: 0.0370 - mean_absolute_error: 0.1019 - val_loss: 0.0732 - val_mean_absolute_error: 0.1328
# Epoch 60/70
# 32/32 [==============================] - 1s 30ms/step - loss: 0.0329 - mean_absolute_error: 0.0872 - val_loss: 0.0711 - val_mean_absolute_error: 0.1201
# Epoch 61/70
# 32/32 [==============================] - 1s 34ms/step - loss: 0.0342 - mean_absolute_error: 0.0848 - val_loss: 0.0680 - val_mean_absolute_error: 0.1065
# Epoch 62/70
# 32/32 [==============================] - 2s 52ms/step - loss: 0.0327 - mean_absolute_error: 0.0783 - val_loss: 0.0623 - val_mean_absolute_error: 0.1051
# Epoch 63/70
# 32/32 [==============================] - 1s 45ms/step - loss: 0.0301 - mean_absolute_error: 0.0730 - val_loss: 0.0803 - val_mean_absolute_error: 0.1268
# Epoch 64/70
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0334 - mean_absolute_error: 0.0742 - val_loss: 0.0702 - val_mean_absolute_error: 0.1053
# Epoch 65/70
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0279 - mean_absolute_error: 0.0706 - val_loss: 0.0851 - val_mean_absolute_error: 0.1271
# Epoch 66/70
# 32/32 [==============================] - 1s 33ms/step - loss: 0.0292 - mean_absolute_error: 0.0652 - val_loss: 0.0751 - val_mean_absolute_error: 0.1140
# Epoch 67/70
# 32/32 [==============================] - 1s 33ms/step - loss: 0.0262 - mean_absolute_error: 0.0610 - val_loss: 0.0743 - val_mean_absolute_error: 0.1089
# Epoch 68/70
# 32/32 [==============================] - 1s 35ms/step - loss: 0.0271 - mean_absolute_error: 0.0613 - val_loss: 0.0769 - val_mean_absolute_error: 0.1129
# Epoch 69/70
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0244 - mean_absolute_error: 0.0575 - val_loss: 0.0750 - val_mean_absolute_error: 0.1068
# Epoch 70/70
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0254 - mean_absolute_error: 0.0575 - val_loss: 0.0659 - val_mean_absolute_error: 0.0968

# %%
compare_sharp_loss(history, 10, 4)

# %%
y_pred  = model2.predict((x_test, x_test_mkb, x_test_harmfull, x_test_prof))
# Out:
# 10/10 [==============================] - 0s 10ms/step

# %%
print(y_pred[0], '-' , y_test[0])
# Out:
# [2.3778973e-04 9.9975216e-01 1.0000872e-05] - [0 1 0]

# %%
y_pred_idx = np.argmax(y_pred, axis=1)
y_test_idx = np.argmax(y_test, axis=1)
df_result = pd.DataFrame({'pred': y_pred_idx, 'test': y_test_idx})
df_result['pred'] = df_result['pred'].apply(MyUtils.resolve_conclusion_map)
df_result['test'] = df_result['test'].apply(MyUtils.resolve_conclusion_map)
display(df_result)
num_wrong = 0
for pred, test in zip(y_pred_idx, y_test_idx):
    if pred != test:
        num_wrong += 1

percent_wrong = num_wrong / len(y_test_idx) * 100
print(f"Percent wrong: {percent_wrong:.2f}%")
# Out:
#       pred   test
# 0    Годен  Годен
# 1    Годен  Годен
# 2    Годен  Годен
# 3    Годен  Годен
# 4    Годен  Годен
# ..     ...    ...
# 308  Годен  Годен
# 309  Годен  Годен
# 310  Годен  Годен
# 311  Годен  Годен
# 312  Годен  Годен
#
# [313 rows x 2 columns]
# Percent wrong: 7.03%

# %%
# Подсчет общего количества значений в столбце test
total_values = df_result['test'].count()

# Подсчет количества несовпадений
num_mismatches = (df_result['pred'] != df_result['test']).sum()

# Подсчет процентного соотношения несовпадений
mismatch_percentage = (num_mismatches / total_values) * 100
mismatch_percentage
# Out:
# 7.0287539936102235

# %%
np.argmax(y_pred, axis = -1).shape
# Out:
# (313,)

# %%
np.argmax(y_test, axis = -1).shape
# Out:
# (313,)

# %%
cm = confusion_matrix(np.argmax(y_test, axis=-1),
                          np.argmax(y_pred, axis=-1),
                          normalize='true')

# %%
cm = np.around(cm, 1)

# %%
MyUtils.conclusion_labels()[np.argmax([1,0,0])]
# Out:
# 'Негоден'

# %%
figsize = (10,10)
title = "model2"
# Отрисовка матрицы ошибок
fig, ax = plt.subplots(figsize=figsize)
ax.set_title(f'Нейросеть {title}: матрица ошибок нормализованная', fontsize=18)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=MyUtils.conclusion_labels())
disp.plot(ax=ax)
plt.gca().images[-1].colorbar.remove()  # Стирание ненужной цветовой шкалы
plt.xlabel('Предсказанные классы', fontsize=16)
plt.ylabel('Верные классы', fontsize=16)
fig.autofmt_xdate(rotation=45)          # Наклон меток горизонтальной оси при необходимости
plt.show()

# %%
# Подсчет матрицы ошибок
cm = confusion_matrix(y_test_idx, y_pred_idx)

# Подсчет количества верных предсказаний
num_correct = cm.diagonal().sum()

# Подсчет количества ошибочных предсказаний
num_mismatches = cm.sum() - num_correct

# Подсчет процентного соотношения несовпадений
mismatch_percentage = (num_mismatches / cm.sum()) * 100

# Вывод результата
print(f'Количество верных предсказаний: {num_correct}')
print(f'Количество ошибочных предсказаний: {num_mismatches}')
print(f'Процентное соотношение несовпадений: {mismatch_percentage:.2f}%')
# Out:
# Количество верных предсказаний: 291
# Количество ошибочных предсказаний: 22
# Процентное соотношение несовпадений: 7.03%

# %%
fig, ax = plt.subplots(figsize=figsize)
ax.scatter(y_test_idx, y_pred_idx)

# %% [markdown]
# **Вывод**: Основная идея объединить МКБ в одну колонку и пройти по ней как по предложению через свертки, для выявления взаимосвязи между специалистами.
#
# Результат слабоватый, возможно из-за слишком несбалансированнной базы
# По этой же причине не стал обрабатывать основные текстовые поля, хотя была та же идея избавится от разрежения значений полей специалистов путём объединения текстов колонок в одну в виде текста с разбивкой на абзацы и заголовками  для каждого специалиста.
# Если будет база со сбалансированными данными, возможно это будет уместно сделать
